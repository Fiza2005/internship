# %%
import pandas as pd

# %%
df=pd.read_csv("/content/titanic uncleaned (1).csv")

# %%
df
# Out:
#       Store Country          State          City Category Clothing Type  \
# 0     Zudio   India      Karnataka         Jalna    Women       Dresses
# 1     Zudio   India        Gujarat         Patna     Kids        Skirts
# 2     Zudio   India  Uttar Pradesh       Kolkata      Men       Hoodies
# 3     Zudio   India    West Bengal       Kolkata    Women       Dresses
# 4     Zudio   India    West Bengal      Guwahati      Men       Dresses
# ...     ...     ...            ...           ...      ...           ...
# 4043  Zudio   India          Delhi        Mumbai      Men         Shoes
# 4044  Zudio   India      Rajasthan          Agra     Kids          Tops
# 4045  Zudio   India          Delhi        Kanpur      Men      T-shirts
# 4046  Zudio   India  Uttar Pradesh  Chhattisgarh     Kids         Pants
# 4047  Zudio   India          Delhi    Coimbatore    Women        Skirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# ...

# %%
df.head(10)
# Out:
#    Store Country          State       City Category Clothing Type  \
# 0  Zudio   India      Karnataka      Jalna    Women       Dresses
# 1  Zudio   India        Gujarat      Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh    Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal    Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal   Guwahati      Men       Dresses
# 5  Zudio   India    West Bengal     Nashik     Kids       Jackets
# 6  Zudio   India    Maharashtra    Lucknow     Kids       Jackets
# 7  Zudio   India    West Bengal  Hyderabad    Women          Tops
# 8  Zudio   India      Karnataka  Ahmedabad      Men         Shoes
# 9  Zudio   India      Karnataka  Hyderabad     Kids         Jeans
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      2022-06-04  ...
# 1            48       404562      Owned      2020-12-19  ...
# ...

# %%
df.tail(10)
# Out:
#       Store Country          State           City Category Clothing Type  \
# 4038  Zudio   India  Uttar Pradesh        Solapur    Women       Hoodies
# 4039  Zudio   India      Karnataka       Vadodara    Women        Shirts
# 4040  Zudio   India    West Bengal  Visakhapatnam    Women         Pants
# 4041  Zudio   India    Maharashtra      Bengaluru      Men       Dresses
# 4042  Zudio   India    West Bengal        Chennai     Kids         Pants
# 4043  Zudio   India          Delhi         Mumbai      Men         Shoes
# 4044  Zudio   India      Rajasthan           Agra     Kids          Tops
# 4045  Zudio   India          Delhi         Kanpur      Men      T-shirts
# 4046  Zudio   India  Uttar Pradesh   Chhattisgarh     Kids         Pants
# 4047  Zudio   India          Delhi     Coimbatore    Women        Skirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# 4038            56       414639     Rented      2024-11-07  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4048 entries, 0 to 4047
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      4048 non-null   object
#  1   Country                    4048 non-null   object
#  2   State                      4048 non-null   object
#  3   City                       4048 non-null   object
#  4   Category                   4048 non-null   object
#  5   Clothing Type              4048 non-null   object
#  6   Store Number               4048 non-null   int64
#  7   Postal Code                4048 non-null   int64
#  8   Store Type                 4048 non-null   object
#  9   Store Open Date            4048 non-null   object
#  10  Selling Area Size (sq ft)  4048 non-null   int64
#  11  Store Manager              4048 non-null   object
#  12  Manager ID                 4048 non-null   object
# ...

# %%
df.shape
# Out:
# (4048, 28)

# %%
df.dtypes
# Out:
# Store                         object
# Country                       object
# State                         object
# City                          object
# Category                      object
# Clothing Type                 object
# Store Number                   int64
# Postal Code                    int64
# Store Type                    object
# Store Open Date               object
# Selling Area Size (sq ft)      int64
# Store Manager                 object
# Manager ID                    object
# Store Address                 object
# Contact Information           object
# Operating Hours               object
# Staff Count                    int64
# Parking Availability          object
# Security Features             object
# Order ID                     float64
# Order Date                    object
# Month                         object
# Customer ID                  float64
# Customer Name                 object
# Product ID                   float64
# ...

# %%
df.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   4048.000000    4048.000000                4048.000000  4048.000000
# mean      50.809289  419792.591403                1110.461957    11.404644
# std       29.056427   11704.231124                 192.873679     5.176194
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       26.000000  409616.500000                 950.000000     7.000000
# 50%       51.000000  419675.000000                1100.000000    11.000000
# 75%       76.000000  430042.250000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   4047.000000    4047.000000  4047.000000  4047.000000  4047.000000
# mean   55050.624907  549387.995552   599.415122  1752.723499     4.497653
# ...

# %%
df['Country']
# Out:
# 0       India
# 1       India
# 2       India
# 3       India
# 4       India
#         ...
# 4043    India
# 4044    India
# 4045    India
# 4046    India
# 4047    India
# Name: Country, Length: 4048, dtype: object

# %%
df[['Country','Month']]
# Out:
#      Country     Month
# 0      India  November
# 1      India      June
# 2      India    August
# 3      India     March
# 4      India     April
# ...      ...       ...
# 4043   India   January
# 4044   India     March
# 4045   India     April
# 4046   India   October
# 4047   India       NaN
#
# [4048 rows x 2 columns]
